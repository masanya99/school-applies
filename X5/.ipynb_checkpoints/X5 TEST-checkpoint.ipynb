# %%
import numpy as np

# %%
a = [1.4, 1.5, 3.2, 1.4, 2.5, 3.4, 3.1, 2.4, 3.8, 2.6]
a
# Out:
# [1.4, 1.5, 3.2, 1.4, 2.5, 3.4, 3.1, 2.4, 3.8, 2.6]

# %% [raw]
# a = a.sort()
# a

# %%
from collections import Counter

# %%
new= Counter(a)
new
# Out:
# Counter({1.4: 2,
#          1.5: 1,
#          3.2: 1,
#          2.5: 1,
#          3.4: 1,
#          3.1: 1,
#          2.4: 1,
#          3.8: 1,
#          2.6: 1})

# %%
new.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-14a3ff56d1ce> in <module>
# ----> 1 new.sort()
#
# AttributeError: 'Counter' object has no attribute 'sort'

# %%
ex = sum(a)/len(a)
ex
# Out:
# 2.5300000000000002

# %%
a = np.array([[3,2],[5,1],[-1,2]])
a
# Out:
# array([[ 3,  2],
#        [ 5,  1],
#        [-1,  2]])

# %%
b = np.array([[2,-3,2], [1,2,1]])
b
# Out:
# array([[ 2, -3,  2],
#        [ 1,  2,  1]])

# %%
c = a@b

# %%
c
# Out:
# array([[  8,  -5,   8],
#        [ 11, -13,  11],
#        [  0,   7,   0]])

# %%
np.linalg.det(c)
# Out:
# -1.7097434579227458e-14

# %%
a= np.array([[4,-5,2],[3,-3,2],[2,-3,1]])
b=np.array([1,2,3])

# %%
np.linalg.inv(a) @ b
# Out:
# array([-11.,  -5.,  10.])

# %%
-11. *  -5. *  10.
# Out:
# 550.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.linalg.inv( [[1,2,1,-1], [1,1,0,0], [0,2,0,-1],[1,1,1,0]])
# Out:
# array([[ 1.,  1., -1., -1.],
#        [-1.,  0.,  1.,  1.],
#        [-0., -1., -0.,  1.],
#        [-2.,  0.,  1.,  2.]])

# %%
def pr(c):
    print(c)

# %%
print(pr(121))
# Out:
# 121
# None

# %%
x = (i for i in range(5))
x
# Out:
# <generator object <genexpr> at 0x7f855d8244d0>

# %%
x = 'Python'
if 'p' in x.upper():
    print(x)
else:
    print(x.lower())
# Out:
# python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
False == False in [False]
# Out:
# True

# %%
[1,2,3] == sorted([3,2,1])
# Out:
# True

# %%
[1,2,3] == [3,2,1].sort()
# Out:
# False

# %%
min({1:2,-1:-2}, key={1:2,-1:-2}.get)==-1
# Out:
# True

# %%
min({1:2,-1:-2}, key={1:2,-1:-2}.get)==2
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [1,2,3]

# %%
arr.remove(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-ed96a712df01> in <module>
# ----> 1 arr.remove(-1)
#
# ValueError: list.remove(x): x not in list

# %%
arr.index(2)
# Out:
# 1

# %%
del arr[arr.index(2)]

# %%
arr
# Out:
# [1, 3]

# %%
arr.pop(-1)
arr
# Out:
# [1, 2]

# %%
arr.pop(arr[-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-c816eb26d5e8> in <module>
# ----> 1 arr.pop(arr[-1])
#
# IndexError: pop index out of range

# %%
print(type(lambda:None))
# Out:
# <class 'function'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re
sum_ = 0 
pattern = 'back'
if re.match(pattern, 'backup.txt'):
    sum_+=1
if re.match(pattern, 'text.back'):
    sum_+=2
if re.search(pattern, 'backup.txt'):
    sum_+=4
if re.search(pattern, 'text.back'):
    sum_+=8
sum_
# Out:
# 13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l =[1,2,3,4,5,6]
def gen():
    it = iter(l)
    next(it)
    yield from it
for i in gen():print(i,end=' ')
# Out:
# 2 3 4 5 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
() is ()
# Out:
# True

# %%
[] is []
# Out:
# False

# %%
True is True and False in (False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-05b424b2fc78> in <module>
# ----> 1 True is True and False in (False)
#
# TypeError: argument of type 'bool' is not iterable

# %%
bool(121%11)
# Out:
# False

# %%
bool(~True)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
None is None
# Out:
# True

# %%
{} is {}
# Out:
# False

# %%
type(None) is None
# Out:
# False

# %%
17 in range(18) != True
# Out:
# True

# %%
'Dima' == "Dima"
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(type((i for _ in range(9))))
# Out:
# <class 'generator'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def gen(*args, **kwargs):
    yield from(args, kwargs)
    
print(list(gen(1,2,a=1,b=2)))
# Out:
# [(1, 2), {'a': 1, 'b': 2}]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def foo(x=[]):
    foo.x =x
    def foo():
        foo.append('bar')
        return foo
    return foo
print(foo()()()()()().x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-90-1a8904b9ad28> in <module>
#       5         return foo
#       6     return foo
# ----> 7 print(foo()()()()()().x)
#
# <ipython-input-90-1a8904b9ad28> in foo(x)
#       1 def foo(x=[]):
# ----> 2     foo.x =x
#       3     def foo():
#       4         foo.append('bar')
#       5         return foo
#
# UnboundLocalError: local variable 'foo' referenced before assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Container:
    data =[]
class List(Container):
    def append(self, data):
        self.data.append(data)
        
l = List(); l.append(1); l.append(2)
print(Container.data)
# Out:
# [1, 2]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Number:
    data = 0
class Int(Number):
    def plus_one(self):
        self.data +=1
i = Int(); i.plus_one(); i.plus_one()
print(Number.data)
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Base: pass
class A(Base): pass
class B(Base): pass
class C(type): pass
class D(A,B,C): pass

# %%
D.__mro__
# Out:
# (__main__.D, __main__.A, __main__.B, __main__.Base, __main__.C, type, object)

# %%
what = lambda arg: set(dir(arg))

# %%
(what([]) & what(()) & what({}) - what(0))
# Out:
# {'__contains__', '__getitem__', '__iter__', '__len__'}

# %%
(what([]) & what({}) - what(()))
# Out:
# {'__delitem__', '__setitem__', 'clear', 'copy', 'pop'}

# %%
(what([]) & what("") - what({}))
# Out:
# {'__add__', '__mul__', '__rmul__', 'count', 'index'}

# %%
(what(gen()) & what([]) - what(gen))
# Out:
# {'__iter__'}
